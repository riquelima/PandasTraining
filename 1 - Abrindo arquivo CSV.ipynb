# %%
# Importando o pandas
import pandas as pd

# %%
# Abrindo o arquivo CSV
df= pd.read_csv("houses_to_rent.csv", encoding = "UTF-8", sep =",")

# %%
# Mostrando a visão do topo da tabela
df.head(10)
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           0     1   240      3         3               4     -      acept
# 1           1     0    64      2         1               1    10      acept
# 2           2     1   443      5         5               4     3      acept
# 3           3     1    73      2         2               1    12      acept
# 4           4     1    19      1         1               0     -  not acept
# 5           5     1    13      1         1               0     2      acept
# 6           6     1    55      1         1               1     2      acept
# 7           7     1    55      2         2               1     2      acept
# 8           8     1    82      3         1               1     3      acept
# 9           9     1    32      1         1               1    16      acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# ...

# %%
# Define o formato da tabela. No caso está está em 6080 linhas e 14 colunas.
df.shape
# Out:
# (6080, 14)

# %%
# Especificando o cabeçalho do arquivo
df= pd.read_csv("houses_to_rent.csv", encoding = "UTF-8", sep =",", header=0)
df.head()
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           0     1   240      3         3               4     -      acept
# 1           1     0    64      2         1               1    10      acept
# 2           2     1   443      5         5               4     3      acept
# 3           3     1    73      2         2               1    12      acept
# 4           4     1    19      1         1               0     -  not acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 3  not furnished    R$700     R$1,250        R$150           R$16   R$2,116
# 4  not furnished      R$0     R$1,200         R$41           R$16   R$1,257

# %%
# Selecionando somente algumas colunas
df= pd.read_csv("houses_to_rent.csv", encoding = "UTF-8", sep =",", usecols=["area", "rent amount"])
df.head()
# Out:
#    area rent amount
# 0   240     R$8,000
# 1    64       R$820
# 2   443     R$7,000
# 3    73     R$1,250
# 4    19     R$1,200

# %%
# Lendo X Linhas do arquivo
df= pd.read_csv("houses_to_rent.csv", encoding = "UTF-8", sep =",", usecols=["area", "rent amount"], nrows=200)

df.head()
# Out:
#    area rent amount
# 0   240     R$8,000
# 1    64       R$820
# 2   443     R$7,000
# 3    73     R$1,250
# 4    19     R$1,200
