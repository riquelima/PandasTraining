# %%
# Importando pandas e abrindo arquivo csv

#Importando pandas e abrindo o arquivo
import pandas as pd
df= pd.read_csv("houses_to_rent_v2.csv")

# %%
# Vetores lógicos no loc
df.loc[0:3]
# Out:
#            city  area  rooms  bathroom  parking spaces floor animal  \
# 0     São Paulo    70      2         1               1     7  acept
# 1     São Paulo   320      4         4               0    20  acept
# 2  Porto Alegre    80      1         1               1     6  acept
# 3  Porto Alegre    51      2         1               0     2  acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 2  not furnished      1000              2800                  0
# 3  not furnished       270              1112                 22
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# 2                   41        3841
# 3                   17        1421

# %%
# Como o pandas realiza operações lógicas no dataframe
#df[df.city == "São Paulo"] -- Dataframe irá buscar as linhas correspondentes a São Paulo
#df[df.rooms > 5] -- Dataframe irá buscar as linhas com quartos maiores que 5
df[df.city == "São Paulo"]
# Out:
#             city  area  rooms  bathroom  parking spaces floor     animal  \
# 0      São Paulo    70      2         1               1     7      acept
# 1      São Paulo   320      4         4               0    20      acept
# 4      São Paulo    25      1         1               0     1  not acept
# 5      São Paulo   376      3         3               7     -      acept
# 7      São Paulo   213      4         4               4     4      acept
# ...          ...   ...    ...       ...             ...   ...        ...
# 10683  São Paulo   280      4         4               2     5      acept
# 10685  São Paulo    83      3         2               2    11      acept
# 10686  São Paulo   150      3         3               2     8  not acept
# 10688  São Paulo   285      4         4               4    17      acept
# 10691  São Paulo    80      2         1               0     -      acept
#
#            furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# ...

# %%
# E e OU  - Selecione somente os aluguéis da cidade de São Paulo que aceitam animais
df[(df.city == "São Paulo") & (df.animal == "acept")].head()
# Out:
#         city  area  rooms  bathroom  parking spaces floor animal  \
# 0  São Paulo    70      2         1               1     7  acept
# 1  São Paulo   320      4         4               0    20  acept
# 5  São Paulo   376      3         3               7     -  acept
# 7  São Paulo   213      4         4               4     4  acept
# 8  São Paulo   152      2         2               1     3  acept
#
#        furniture  hoa (R$)  rent amount (R$)  property tax (R$)  \
# 0      furnished      2065              3300                211
# 1  not furnished      1200              4960               1750
# 5  not furnished         0              8000                834
# 7  not furnished      2254              3223               1735
# 8      furnished      1000             15000                250
#
#    fire insurance (R$)  total (R$)
# 0                   42        5618
# 1                   63        7973
# 5                  121        8955
# 7                   41        7253
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-9510dcb640ab> in <module>
#       1 # E e OU - Selecione somente aluguéis da cidade de São Paulo que aceitem animais e mostre o valor total de cada e o tamanho
# ----> 2 df[(df.city == "São Paulo") & (df.animal == "acept")] + df.total
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'total'

# %%
df.head()
